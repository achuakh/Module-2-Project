# %%
# !pip install duckdb sqlalchemy pandas matplotlib jupyterlab jupysql
# Out:
# Requirement already satisfied: duckdb in ./miniconda3/envs/pds/lib/python3.10/site-packages (1.1.3)
# Requirement already satisfied: sqlalchemy in ./miniconda3/envs/pds/lib/python3.10/site-packages (1.4.39)
# Requirement already satisfied: pandas in ./miniconda3/envs/pds/lib/python3.10/site-packages (1.5.3)
# Requirement already satisfied: matplotlib in ./miniconda3/envs/pds/lib/python3.10/site-packages (3.7.1)
# Requirement already satisfied: jupyterlab in ./miniconda3/envs/pds/lib/python3.10/site-packages (4.3.4)
# Requirement already satisfied: jupysql in ./miniconda3/envs/pds/lib/python3.10/site-packages (0.11.1)
# Requirement already satisfied: greenlet!=0.4.17 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from pandas) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: contourpy>=1.0.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: async-lru>=1.0.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (0.28.1)
# Requirement already satisfied: ipykernel>=6.5.0 in ./.local/lib/python3.10/site-packages (from jupyterlab) (6.29.5)
# Requirement already satisfied: jinja2>=3.0.3 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (3.1.6)
# Requirement already satisfied: jupyter-core in ./.local/lib/python3.10/site-packages (from jupyterlab) (5.8.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (2.2.5)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (2.15.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (0.2.4)
# Requirement already satisfied: setuptools>=40.8.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (78.1.1)
# Requirement already satisfied: tomli>=1.2.2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab) (2.0.1)
# Requirement already satisfied: tornado>=6.2.0 in ./.local/lib/python3.10/site-packages (from jupyterlab) (6.5.1)
# Requirement already satisfied: traitlets in ./.local/lib/python3.10/site-packages (from jupyterlab) (5.14.3)
# Requirement already satisfied: anyio>=3.1.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (4.7.0)
# Requirement already satisfied: argon2-cffi>=21.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in ./.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (8.6.3)
# Requirement already satisfied: jupyter-events>=0.11.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.21.1)
# Requirement already satisfied: pyzmq>=24 in ./.local/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (26.4.0)
# Requirement already satisfied: send2trash>=1.8.2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (0.17.1)
# Requirement already satisfied: websocket-client>=1.7 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab) (1.8.0)
# Requirement already satisfied: babel>=2.10 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.16.0)
# Requirement already satisfied: json5>=0.9.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (0.9.25)
# Requirement already satisfied: jsonschema>=4.18.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (4.23.0)
# Requirement already satisfied: requests>=2.31 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab) (2.32.3)
# Requirement already satisfied: prettytable>=3.12.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupysql) (3.16.0)
# Requirement already satisfied: sqlparse in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupysql) (0.5.3)
# Requirement already satisfied: ipython-genutils>=0.1.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupysql) (0.2.0)
# Requirement already satisfied: sqlglot>=11.3.7 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupysql) (26.25.3)
# Requirement already satisfied: jupysql-plugin>=0.4.2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupysql) (0.4.5)
# Requirement already satisfied: ploomber-core>=0.2.7 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupysql) (0.2.26)
# Requirement already satisfied: exceptiongroup>=1.0.2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.2.0)
# Requirement already satisfied: idna>=2.8 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.7)
# Requirement already satisfied: sniffio>=1.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: typing_extensions>=4.5 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.2)
# Requirement already satisfied: argon2-cffi-bindings in ./miniconda3/envs/pds/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (21.2.0)
# Requirement already satisfied: certifi in ./miniconda3/envs/pds/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (2025.4.26)
# Requirement already satisfied: httpcore==1.* in ./miniconda3/envs/pds/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab) (0.14.0)
# Requirement already satisfied: comm>=0.1.1 in ./.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.2.2)
# Requirement already satisfied: debugpy>=1.6.5 in ./.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.8.14)
# Requirement already satisfied: ipython>=7.23.1 in ./.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (8.37.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in ./.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (0.1.7)
# Requirement already satisfied: nest-asyncio in ./.local/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (1.6.0)
# Requirement already satisfied: psutil in ./miniconda3/envs/pds/lib/python3.10/site-packages (from ipykernel>=6.5.0->jupyterlab) (5.9.0)
# Requirement already satisfied: decorator in ./.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in ./.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.19.2)
# Requirement already satisfied: pexpect>4.3 in ./.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.19.1)
# Requirement already satisfied: stack_data in ./.local/lib/python3.10/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.6.3)
# Requirement already satisfied: wcwidth in ./miniconda3/envs/pds/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in ./.local/lib/python3.10/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jinja2>=3.0.3->jupyterlab) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab) (0.22.3)
# Requirement already satisfied: platformdirs>=2.5 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-core->jupyterlab) (4.3.7)
# Requirement already satisfied: python-json-logger>=2.0.4 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.2.1)
# Requirement already satisfied: pyyaml>=5.3 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (6.0.2)
# Requirement already satisfied: rfc3339-validator in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (0.1.1)
# Requirement already satisfied: fqdn in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.1)
# Requirement already satisfied: isoduration in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (3.0.0)
# Requirement already satisfied: uri-template in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (6.2.0)
# Requirement already satisfied: defusedxml in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (3.1.2)
# Requirement already satisfied: nbclient>=0.5.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.5.0)
# Requirement already satisfied: webencodings in ./miniconda3/envs/pds/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.20.0)
# Requirement already satisfied: ptyprocess>=0.5 in ./.local/lib/python3.10/site-packages (from pexpect>4.3->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.7.0)
# Requirement already satisfied: posthog in ./miniconda3/envs/pds/lib/python3.10/site-packages (from ploomber-core>=0.2.7->jupysql) (4.3.2)
# Requirement already satisfied: six>=1.5 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from python-dateutil>=2.8.1->pandas) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab) (2.3.0)
# Requirement already satisfied: cffi>=1.0.1 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (1.17.1)
# Requirement already satisfied: pycparser in ./miniconda3/envs/pds/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab) (2.21)
# Requirement already satisfied: soupsieve>1.2 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab) (2.5)
# Requirement already satisfied: arrow>=0.15.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab) (2.9.0.20250516)
# Requirement already satisfied: backoff>=1.10.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (2.2.1)
# Requirement already satisfied: distro>=1.5.0 in ./miniconda3/envs/pds/lib/python3.10/site-packages (from posthog->ploomber-core>=0.2.7->jupysql) (1.9.0)
# Requirement already satisfied: executing>=1.2.0 in ./.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (2.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in ./.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (3.0.0)
# Requirement already satisfied: pure-eval in ./.local/lib/python3.10/site-packages (from stack_data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab) (0.2.3)

# %%
import duckdb
import sqlalchemy
import matplotlib.pyplot as plt
import pandas as pd

con = duckdb.connect("NTUdb")

# %%
engine = sqlalchemy.create_engine("duckdb:///NTUdb.db")

# %%
# SQL query to aggregate monthly sales
query = """
SELECT 
    DATE_TRUNC('month', order_purchase_timestamp) AS order_month,
    SUM(TOTAL_PAYMENT) AS total_sales
FROM OLIST.FCT_ORDERS
WHERE order_status = 'delivered'
GROUP BY order_month
ORDER BY order_month;
"""

# %%
df = con.execute(query).fetchdf()  
print(df.head())
# Out:
#   order_month  total_sales
# 0  2016-09-01         0.00
# 1  2016-10-01     46566.71
# 2  2016-12-01        19.62
# 3  2017-01-01    127545.67
# 4  2017-02-01    271298.65

# %%
plt.figure(figsize=(12,6))
plt.plot(df['order_month'], df['total_sales'], marker='o', linestyle='-')
plt.title('Monthly Sales Trend')
plt.xlabel('Month')
plt.ylabel('Total Sales (USD)')
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
