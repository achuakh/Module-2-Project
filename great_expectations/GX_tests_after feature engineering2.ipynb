# %%
import numpy as np
import pandas as pd
import duckdb
import sqlalchemy
from pandas_gbq import read_gbq

# %%
import great_expectations as gx
from great_expectations import expectations as gxe

import pprint
import os

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_CUSTOMERS

# %%
context = gx.get_context()
# query bigquery
project_id = "projectm2-aiess"
query = "SELECT * FROM olist_brazilian_ecommerce_target.DIM_CUSTOMERS"
df_customers = read_gbq(query, project_id=project_id)


data_source_name = "olist_brazilian_ecommerce_target.DIM_CUSTOMERS"
data_source = context.data_sources.add_pandas(name=data_source_name)
# Out:
# Downloading: 100%|██████████|

# %%
# create asset
data_asset_name = "olist_brazilian_ecommerce_target.DIM_CUSTOMERS_asset"
data_asset = data_source.add_dataframe_asset(name=data_asset_name)

# %%
# create batch
batch_definition_name = "batch_DIM_CUSTOMERS_dataframe"
batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

batch_parameters = {"dataframe": df_customers}

new_batch = batch_definition.get_batch(batch_parameters=batch_parameters)

# %%
print(new_batch.head(4))
# Out:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 226.90it/s]
#                     pk_customer_sid                customer_unique_id  \
# 0  10ad09201fcc1c82d181ff7234bcdb3b  94742cd1fbac9146be7e2a139b63e13c
# 1  8a0108267d9258a0ec9f74381bc9b0de  7a2dc4682890550ebe3b8befcea3d55c
# 2  888d2ebe1af2a8c93c75dae5dfc23719  721d1092e1a6460c67e6a0e691d899a3
# 3  dad907e170748a35ef4e92238b7308f3  36b1c0516f123351ffa87430416dcae5
#
#   customer_zip_code_prefix customer_city customer_state  \
# 0                    69900    rio branco             AC
# 1                    69900    rio branco             AC
# 2                    69900    rio branco             AC
# 3                    69900    rio branco             AC
#
#                 load_date
# 0  2025-06-18 03:31:23 AM
# 1  2025-06-18 03:31:23 AM
# 2  2025-06-18 03:31:23 AM
# 3  2025-06-18 03:31:23 AM

# %%
# Create a new suite for all dimension tables schema validation
suite_name = "schema_DIM_CUSTOMERS_expectation"
suite = gx.ExpectationSuite(name=suite_name)

schema_DIM_CUSTOMERS_expectation = gx.expectations.ExpectColumnToExist(
    column="pk_customer_sid", column_index=0
)

context.suites.add_or_update(suite)
suite.add_expectation(schema_DIM_CUSTOMERS_expectation)

definition_name = "schema_DIM_CUSTOMERS_definition"
validation_definition = gx.ValidationDefinition(
    data=batch_definition, suite=suite, name=definition_name
)

# %%
validation_results = validation_definition.run(batch_parameters=batch_parameters)
print(validation_results)
# Out:
# Calculating Metrics: 100%|██████████| 2/2 [00:00<00:00, 429.35it/s]
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_CUSTOMERS-olist_brazilian_ecommerce_target.DIM_CUSTOMERS_asset",
#           "column": "pk_customer_sid",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "fdd40240-1684-48aa-81c6-0ed9dbcb4a92"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "schema_DIM_CUSTOMERS_expectation",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 1,
#     "successful_expectations": 1,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163155.793593Z",
#       "pandas_data_fingerprint": "a042d1778257861e20708b00e390f103"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.DIM_CUSTOMERS",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.DIM_CUSTOMERS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "a9259edd-dd25-488b-8e3b-6182f03b9cb9",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:31:55.948320+08:00"
#     },
#     "validation_time": "2025-06-19T16:31:55.948320+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %%
# Save full results to file
output_folder = "gx_output"
os.makedirs(output_folder, exist_ok=True)
result_path = os.path.join(output_folder, "gx_results_DIM_CUSTOMERS_schema_check.txt")

with open(result_path, "w") as f:
    f.write(pprint.pformat(validation_results))

print(f" Full GX test results saved to {result_path}")
# Out:
#  Full GX test results saved to gx_output/gx_results_DIM_CUSTOMERS_schema_check.txt

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_PK_SCHEMA_CHECK 1/2

# %%
context = gx.get_context()

# List of GBQ dimension tables and their primary key columns with dtypes
gbq_tables_with_columns_index_and_types = {
    "olist_brazilian_ecommerce_target.DIM_DATE": [
        {"column": "pk_date_sid", "column_index": 0, "type": "object"}
    ],
    "olist_brazilian_ecommerce_target.LKP_STATUS_DESC": [
        {"column": "order_status", "column_index": 0, "type": "object"},
        {"column": "payment_status", "column_index": 1, "type": "object"}
    ],
    "olist_brazilian_ecommerce_target.DIM_ORDERS": [
        {"column": "pk_order_sid", "column_index": 0, "type": "object"}
    ],
    "olist_brazilian_ecommerce_target.DIM_GEOLOCATION": [
        {"column": "geolocation_zip_code_prefix", "column_index": 0, "type": "object"}
    ],
}

# Iterate over the list of tables and process each one
for table_name, expected_columns in gbq_tables_with_columns_index_and_types.items():
    # Query the table from GBQ
    query = f"SELECT * FROM {table_name}"
    df_table = read_gbq(query, project_id="projectm2-aiess")

    # Generate unique names for data source and asset
    data_source_name = f"{table_name}_data_source"
    asset_name = f"{table_name}_asset"

    # Add data source
    data_source = context.data_sources.add_pandas(name=data_source_name)

    # Add DataFrame asset
    data_asset = data_source.add_dataframe_asset(name=asset_name)

    # Add batch definition
    batch_definition_name = table_name
    batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

    # Get the batch and print the first few rows
    batch_parameters = {"dataframe": df_table}
    batch = batch_definition.get_batch(batch_parameters=batch_parameters)
    print(f"Batch for {table_name}:")
    print(batch.head(4))

    # Create Expectation Suite
    suite_name = f"{table_name}_expectation_suite"
    suite = gx.ExpectationSuite(name=suite_name)
    suite = context.suites.add_or_update(suite)

    # Add expectations for each expected column
    for column_info in expected_columns:
        column = column_info["column"]
        column_index = column_info["column_index"]
        column_type = column_info["type"]

        column_expectation = gx.expectations.ExpectColumnToExist(
            column=column, column_index=column_index
        )
        suite.add_expectation(column_expectation)

        dtype_expectation = gx.expectations.ExpectColumnValuesToBeOfType(
            column=column, type_=column_type
        )
        suite.add_expectation(dtype_expectation)

    # Create validation definition
    definition_name = f"{table_name}_validation_definition"
    validation_definition = gx.ValidationDefinition(
        data=batch_definition, suite=suite, name=definition_name
    )

    # Run validation
    validation_results = validation_definition.run(batch_parameters=batch_parameters)
    print(f"Validation results for {table_name}:")
    print(validation_results)
# Out:
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.DIM_DATE:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 246.00it/s]
#   pk_date_sid   full_date  year  month month_name  day_of_month  day_name  \
# 0    20150104  2015-01-04  2015      1    January             4    Sunday
# 1    20150111  2015-01-11  2015      1    January            11    Sunday
# 2    20160107  2016-01-07  2016      1    January             7  Thursday
# 3    20190105  2019-01-05  2019      1    January             5  Saturday
#
#    is_weekday               load_date
# 0           0  2025-06-18 03:31:28 AM
# 1           0  2025-06-18 03:31:28 AM
# 2           1  2025-06-18 03:31:28 AM
# 3           0  2025-06-18 03:31:28 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 596.77it/s]
# Validation results for olist_brazilian_ecommerce_target.DIM_DATE:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_DATE_data_source-olist_brazilian_ecommerce_target.DIM_DATE_asset",
#           "column": "pk_date_sid",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "f7933167-42c4-4af9-812f-8cbca389a7e6"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_DATE_data_source-olist_brazilian_ecommerce_target.DIM_DATE_asset",
#           "column": "pk_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "ce1f6913-3fc0-4381-967a-14499f8d346c"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.DIM_DATE_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 2,
#     "successful_expectations": 2,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163159.631072Z",
#       "pandas_data_fingerprint": "756fac0bb634e4542e00af89bfd9f7f8"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.DIM_DATE_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.DIM_DATE_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "ddfc9294-f68f-4773-9485-ff3ed18f0c8a",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:31:59.660120+08:00"
#     },
#     "validation_time": "2025-06-19T16:31:59.660120+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.LKP_STATUS_DESC:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 250.12it/s]
#   order_status payment_status  record_count profit_lost  \
# 0     Invoiced      Completed           273      Profit
# 1   Processing      Completed           269      Profit
# 2  Unavailable      Completed             6      Profit
# 3     Canceled      Completed           411      Profit
#
#                                   status_description
# 0               Invoice processed, payment received.
# 1           Order finalized with successful payment.
# 2      Payment received despite item unavailability.
# 3  Payment was completed despite order cancellation.
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 238.74it/s]
# Validation results for olist_brazilian_ecommerce_target.LKP_STATUS_DESC:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_data_source-olist_brazilian_ecommerce_target.LKP_STATUS_DESC_asset",
#           "column": "order_status",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "7e935a1e-214a-4a2c-b0c8-98625da4f8fc"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_data_source-olist_brazilian_ecommerce_target.LKP_STATUS_DESC_asset",
#           "column": "order_status",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "574fcb90-a09f-49c4-b93a-f80f17c7e866"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_data_source-olist_brazilian_ecommerce_target.LKP_STATUS_DESC_asset",
#           "column": "payment_status",
#           "column_index": 1
#         },
#         "meta": {},
#         "id": "7d73adab-3969-411c-badc-fa847ce31202"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_data_source-olist_brazilian_ecommerce_target.LKP_STATUS_DESC_asset",
#           "column": "payment_status",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "0b2ae31d-f135-4576-953b-29c37b16b667"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 4,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163200.646416Z",
#       "pandas_data_fingerprint": "edfefd6be576e8192ae311950678b867"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.LKP_STATUS_DESC_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "f2535cbd-5ec6-46e1-8062-85073006be4b",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:32:00.695507+08:00"
#     },
#     "validation_time": "2025-06-19T16:32:00.695507+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.DIM_ORDERS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 269.25it/s]
#                        pk_order_sid                   fk_customer_sid  \
# 0  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 1  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 2  2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
# 3  e5215415bb6f76fe3b7cb68103a0d1c0  b6f6cbfc126f1ae6723fe2f9b3751208
#
#   fk_order_purchased_date_sid fk_order_approved_at_date_sid  \
# 0                    20160913                      20161007
# 1                    20160915                      20160915
# 2                    20160904                      20161007
# 3                    20161022                          None
#
#   fk_order_delivered_carrier_date_sid fk_order_delivered_customer_date_sid  \
# 0                                None                                 None
# 1                            20161107                             20161109
# 2                            20161018                                 None
# 3                                None                                 None
#
#   fk_order_estimated_delivery_date_sid order_status  total_payment  order_amt  \
# 0                             20160930     canceled          40.95        NaN
# 1                             20161004    delivered            NaN     134.97
# 2                             20161020      shipped         136.23      72.89
# 3                             20161024     canceled          61.99        NaN
#
#    freight_amt  total_order_amt_wf_freight  balance_amt  \
# 0          NaN                         NaN          NaN
# 1         8.49                      143.46          NaN
# 2        63.34                      136.23          0.0
# 3          NaN                         NaN          NaN
#
#           payment_status  order_purchase_timestamp         order_approved_at  \
# 0  order items not found 2016-09-13 15:24:19+00:00 2016-10-07 13:16:46+00:00
# 1     payments not found 2016-09-15 12:16:38+00:00 2016-09-15 12:16:38+00:00
# 2            in progress 2016-09-04 21:15:19+00:00 2016-10-07 13:18:03+00:00
# 3  order items not found 2016-10-22 08:25:27+00:00                       NaT
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                          NaT                           NaT
# 1    2016-11-07 17:11:53+00:00     2016-11-09 07:47:38+00:00
# 2    2016-10-18 13:14:51+00:00                           NaT
# 3                          NaT                           NaT
#
#   order_estimated_delivery_date               load_date
# 0     2016-09-30 00:00:00+00:00  2025-06-18 03:31:37 AM
# 1     2016-10-04 00:00:00+00:00  2025-06-18 03:31:37 AM
# 2     2016-10-20 00:00:00+00:00  2025-06-18 03:31:37 AM
# 3     2016-10-24 00:00:00+00:00  2025-06-18 03:31:37 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 591.36it/s]
# Validation results for olist_brazilian_ecommerce_target.DIM_ORDERS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "pk_order_sid",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "80ea5dff-16fb-47b4-9ec3-23ecfa2df57b"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "pk_order_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "2005d105-ffa5-4ee4-a80f-7da1bc8822d4"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.DIM_ORDERS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 2,
#     "successful_expectations": 2,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163306.269824Z",
#       "pandas_data_fingerprint": "1f74059bccd1349eb63d2e96e9b6eaed"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "a5cd54cb-488f-4795-9e29-03577fe94e0d",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:33:06.446859+08:00"
#     },
#     "validation_time": "2025-06-19T16:33:06.446859+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.DIM_GEOLOCATION:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 314.37it/s]
#   geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                       81470       -25.571748       -49.334374
# 1                       28930       -22.969370       -42.029834
# 2                       87365       -24.271860       -53.069433
# 3                       87365       -24.281905       -53.074516
#
#      geolocation_city geolocation_state               load_date
# 0            * cidade                PR  2025-06-18 03:31:31 AM
# 1  ...arraial do cabo                RJ  2025-06-18 03:31:31 AM
# 2      4o. centenario                PR  2025-06-18 03:31:31 AM
# 3       4º centenario                PR  2025-06-18 03:31:31 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 449.98it/s]
# Validation results for olist_brazilian_ecommerce_target.DIM_GEOLOCATION:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_GEOLOCATION_data_source-olist_brazilian_ecommerce_target.DIM_GEOLOCATION_asset",
#           "column": "geolocation_zip_code_prefix",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "d254f623-be89-49b8-940e-bc447128fb11"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_GEOLOCATION_data_source-olist_brazilian_ecommerce_target.DIM_GEOLOCATION_asset",
#           "column": "geolocation_zip_code_prefix",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "985fb8f6-886c-4588-91a2-9a801d14284e"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.DIM_GEOLOCATION_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 2,
#     "successful_expectations": 2,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163456.031808Z",
#       "pandas_data_fingerprint": "01326265c5e59629d75aae2b8a2ed35c"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.DIM_GEOLOCATION_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.DIM_GEOLOCATION_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "67fcdbfd-fb79-4d80-86a1-84dd85944596",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:34:56.290700+08:00"
#     },
#     "validation_time": "2025-06-19T16:34:56.290700+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %%
# Save full results to file
output_folder = "gx_output"
os.makedirs(output_folder, exist_ok=True)
result_path = os.path.join(output_folder, "gx_results_DIM_Tables_primary_key_check.txt")

with open(result_path, "w") as f:
    f.write(pprint.pformat(validation_results))

print(f" Full GX test results saved to {result_path}")
# Out:
#  Full GX test results saved to gx_output/gx_results_DIM_Tables_primary_key_check.txt

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_PK_SCHEMA_CHECK 2/2

# %%
context = gx.get_context()

# List of GBQ fact tables and their primary columns with dtypes
gbq_tables_with_columns_index_and_types = {
    "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS": [
        {"column": "pk_order_id", "column_index": 1, "type": "object"},
        {"column": "pk_order_item_id", "column_index": 2, "type": "object"},
    ],
    "olist_brazilian_ecommerce_target.FCT_PAYMENTS": [
        {"column": "pk_order_id", "column_index": 1, "type": "object"},
        {"column": "pk_payment_sequential", "column_index": 2, "type": "int64"}
    ],
    "olist_brazilian_ecommerce_target.FCT_REVIEWS": [
        {"column": "pk_order_id", "column_index": 1, "type": "object"},
        {"column": "pk_review_id", "column_index": 2, "type": "object"},
    ],
}

# Iterate over the list of tables and process each one
for table_name, expected_columns in gbq_tables_with_columns_index_and_types.items():
    # Query the table from GBQ
    query = f"SELECT * FROM {table_name}"
    df_table = read_gbq(query, project_id="projectm2-aiess")

    # Generate unique names for data source and asset
    data_source_name = f"{table_name}_data_source"
    asset_name = f"{table_name}_asset"

    # Add data source
    data_source = context.data_sources.add_pandas(name=data_source_name)

    # Add DataFrame asset
    data_asset = data_source.add_dataframe_asset(name=asset_name)

    # Add batch definition
    batch_definition_name = table_name
    batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

    # Get the batch and print the first few rows
    batch_parameters = {"dataframe": df_table}
    batch = batch_definition.get_batch(batch_parameters=batch_parameters)
    print(f"Batch for {table_name}:")
    print(batch.head(4))

    # Create Expectation Suite
    suite_name = f"{table_name}_expectation_suite"
    suite = gx.ExpectationSuite(name=suite_name)
    suite = context.suites.add_or_update(suite)

    # Add expectations for each expected column
    for column_info in expected_columns:
        column = column_info["column"]
        column_index = column_info["column_index"]
        column_type = column_info["type"]

        column_expectation = gx.expectations.ExpectColumnToExist(
            column=column, column_index=column_index
        )
        suite.add_expectation(column_expectation)

        dtype_expectation = gx.expectations.ExpectColumnValuesToBeOfType(
            column=column, type_=column_type
        )
        suite.add_expectation(dtype_expectation)

    # Create validation definition
    definition_name = f"{table_name}_validation_definition"
    validation_definition = gx.ValidationDefinition(
        data=batch_definition, suite=suite, name=definition_name
    )

    # Run validation
    validation_results = validation_definition.run(batch_parameters=batch_parameters)
    print(f"Validation results for {table_name}:")
    print(validation_results)
# Out:
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 300.30it/s]
#                        fk_order_sid                       pk_order_id  \
# 0  7f39ba4c9052be115350065d07583cac  7f39ba4c9052be115350065d07583cac
# 1  9dc8d1a6f16f1b89874c29c9d8d30447  9dc8d1a6f16f1b89874c29c9d8d30447
# 2  d455a8cb295653b55abda06d434ab492  d455a8cb295653b55abda06d434ab492
# 3  5d70582531ed37f284797ba1354e0c50  5d70582531ed37f284797ba1354e0c50
#
#   pk_order_item_id fk_shipping_limit_date_sid  \
# 0                1                   20171024
# 1                1                   20171018
# 2                1                   20171012
# 3                1                   20170330
#
#                          product_id                         seller_id  \
# 0  a2ff5a97bf95719e38ea2e3b4105bce8  0015a82c2db000af6aaaf3ae2ecb0532
# 1  a2ff5a97bf95719e38ea2e3b4105bce8  0015a82c2db000af6aaaf3ae2ecb0532
# 2  a2ff5a97bf95719e38ea2e3b4105bce8  0015a82c2db000af6aaaf3ae2ecb0532
# 3  08574b074924071f4e201e151b152b4e  001cca7ae9ae17fb1caed9dfb1094831
#
#         shipping_limit_date  price  freight_value product_category_name  ...  \
# 0 2017-10-24 23:56:20+00:00  895.0          21.02       eletroportateis  ...
# 1 2017-10-18 14:49:22+00:00  895.0          21.02       eletroportateis  ...
# 2 2017-10-12 22:24:16+00:00  895.0          21.02       eletroportateis  ...
# 3 2017-03-30 13:10:09+00:00   69.9          31.23    ferramentas_jardim  ...
#
#   product_description_length  product_photos_qty  product_weight_g  \
# 0                        849                   2             11800
# 1                        849                   2             11800
# 2                        849                   2             11800
# 3                        450                   1              9000
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0                 40                 43                36
# 1                 40                 43                36
# 2                 40                 43                36
# 3                 42                 12                39
#
#    seller_zip_code_prefix  seller_city seller_state               load_date
# 0                   09080  santo andre           SP  2025-06-18 03:31:47 AM
# 1                   09080  santo andre           SP  2025-06-18 03:31:47 AM
# 2                   09080  santo andre           SP  2025-06-18 03:31:47 AM
# 3                   29156    cariacica           ES  2025-06-18 03:31:47 AM
#
# [4 rows x 22 columns]
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 550.87it/s]
# Validation results for olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "pk_order_id",
#           "column_index": 1
#         },
#         "meta": {},
#         "id": "4a4bbcf1-b1f2-4bf4-8ee8-125860178bb6"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "pk_order_id",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "38bf926e-6eff-4d87-8201-839ba91f9889"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "pk_order_item_id",
#           "column_index": 2
#         },
#         "meta": {},
#         "id": "f01d8a30-3ffb-46dc-a925-532ce3114798"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "pk_order_item_id",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "30f5119b-47fa-45e1-9adf-85cfbb229b94"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 4,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163551.558854Z",
#       "pandas_data_fingerprint": "7dc15ba813450f7ca2cc0f314c3089d1"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "01dae325-3289-4015-8e25-07df47a9efad",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:35:51.915102+08:00"
#     },
#     "validation_time": "2025-06-19T16:35:51.915102+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.FCT_PAYMENTS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 283.13it/s]
#                        fk_order_sid                       pk_order_id  \
# 0  e6670c9089973cc68e5b90b7d1f4fec4  e6670c9089973cc68e5b90b7d1f4fec4
# 1  d022bdad33a575ca5edb8c4d51e44310  d022bdad33a575ca5edb8c4d51e44310
# 2  90ea2b1be9c98c67406de151652daa63  90ea2b1be9c98c67406de151652daa63
# 3  033e33708df28579692a3d19492c6553  033e33708df28579692a3d19492c6553
#
#    pk_payment_sequential payment_type  payment_installments  payment_value  \
# 0                      1  credit_card                     1          88.49
# 1                      1       boleto                     1          70.03
# 2                      1       boleto                     1          59.22
# 3                      1  credit_card                     1         145.57
#
#                 load_date
# 0  2025-06-18 03:31:51 AM
# 1  2025-06-18 03:31:51 AM
# 2  2025-06-18 03:31:51 AM
# 3  2025-06-18 03:31:51 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 603.96it/s]
# Validation results for olist_brazilian_ecommerce_target.FCT_PAYMENTS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source-olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#           "column": "pk_order_id",
#           "column_index": 1
#         },
#         "meta": {},
#         "id": "db2f537b-5880-4079-aa1a-76a4964a8eae"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source-olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#           "column": "pk_order_id",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "774bdb3e-8850-4503-9393-1c781a3cb4c7"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source-olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#           "column": "pk_payment_sequential",
#           "column_index": 2
#         },
#         "meta": {},
#         "id": "dad33044-f4bf-4035-a17b-59dc2b605065"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source-olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#           "column": "pk_payment_sequential",
#           "type_": "int64"
#         },
#         "meta": {},
#         "id": "2c6ad815-b156-41fe-b8ab-5c4cb5c70edd"
#       },
#       "result": {
#         "observed_value": "int64"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 4,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163619.113763Z",
#       "pandas_data_fingerprint": "f3ba4ad23ff07e14000b1877336df974"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "0750dec6-5bd6-411f-91e6-8a4d713757ab",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:36:19.265162+08:00"
#     },
#     "validation_time": "2025-06-19T16:36:19.265162+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.FCT_REVIEWS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 302.29it/s]
#                        fk_order_sid                       pk_order_id  \
# 0  809a282bbd5dbcabb6f2f724fca862ec  809a282bbd5dbcabb6f2f724fca862ec
# 1  bfbd0f9bdef84302105ad712db648a6c  bfbd0f9bdef84302105ad712db648a6c
# 2  e5215415bb6f76fe3b7cb68103a0d1c0  e5215415bb6f76fe3b7cb68103a0d1c0
# 3  8beb59392e21af5eb9547ae1a9938d06  8beb59392e21af5eb9547ae1a9938d06
#
#                        pk_review_id fk_review_creation_date_sid  review_score  \
# 0  69ac6a27fde9855ebeaaecac0f78058b                    20161002             1
# 1  6916ca4502d6d3bfd39818759d55d536                    20161006             1
# 2  49f695dffa457eaba90d388a5c37e942                    20161009             1
# 3  b28309e8253951a954123e039d3242f7                    20161020             1
#
#   review_comment_title                             review_comment_message  \
# 0                       MEU PEDIDO NÃO FOI ENTREGUE E NÃO FOI DADA NEN...
# 1                          nao recebi o produto e nem resposta da empresa
# 2                       PRODUTO NÃO CHEGOU,E JÁ PASSOU O PRAZO DE ENTREGA
# 3                       Produto não foi entregue. Não foi enviada nota...
#
#        review_creation_date   review_answer_timestamp               load_date
# 0 2016-10-02 00:00:00+00:00 2016-10-26 12:31:00+00:00  2025-06-18 03:31:55 AM
# 1 2016-10-06 00:00:00+00:00 2016-10-07 18:32:28+00:00  2025-06-18 03:31:55 AM
# 2 2016-10-09 00:00:00+00:00 2016-10-11 14:31:29+00:00  2025-06-18 03:31:55 AM
# 3 2016-10-20 00:00:00+00:00 2016-10-24 17:18:09+00:00  2025-06-18 03:31:55 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 589.50it/s]
# Validation results for olist_brazilian_ecommerce_target.FCT_REVIEWS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "pk_order_id",
#           "column_index": 1
#         },
#         "meta": {},
#         "id": "c88efc3e-9553-4480-a9c2-ffbd9c41ea51"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "pk_order_id",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "fc2b8019-a738-4934-a9ad-1753347c916e"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "pk_review_id",
#           "column_index": 2
#         },
#         "meta": {},
#         "id": "ea8aac3a-7543-4c38-914e-fd6f09b9294b"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "pk_review_id",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "5648a569-732d-4e0e-b52c-2fb0aae8c872"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.FCT_REVIEWS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 4,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163707.477807Z",
#       "pandas_data_fingerprint": "ee935aa04f5515de286d3cbdf7b59ce0"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "0da4cf1d-d347-4c44-b52a-fd29f02f836a",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:37:07.730163+08:00"
#     },
#     "validation_time": "2025-06-19T16:37:07.730163+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_FK_Schema_Check_ORDERS

# %%
context = gx.get_context()

# List of GBQ dimension table and the foreign key columns with dtypes
gbq_tables_with_columns_index_and_types = {
    "olist_brazilian_ecommerce_target.DIM_ORDERS": [
        {"column": "fk_customer_sid", "column_index": 1, "type": "object"},
        {"column": "fk_order_purchased_date_sid", "column_index": 2, "type": "object"},
        {"column": "fk_order_approved_at_date_sid", "column_index": 3, "type": "object"},
        {"column": "fk_order_delivered_carrier_date_sid", "column_index": 4, "type": "object"},
        {"column": "fk_order_delivered_customer_date_sid", "column_index": 5, "type": "object"},
        {"column": "fk_order_estimated_delivery_date_sid", "column_index": 6, "type": "object"},
        {"column": "order_status", "column_index": 7, "type": "object"},
        {"column": "payment_status", "column_index": 8, "type": "object"} ]
}

# Iterate over the list of tables and process each one
for table_name, expected_columns in gbq_tables_with_columns_index_and_types.items():
    # Query the table from GBQ
    query = f"SELECT * FROM {table_name}"
    df_table = read_gbq(query, project_id="projectm2-aiess")

    # Generate unique names for data source and asset
    data_source_name = f"{table_name}_data_source"
    asset_name = f"{table_name}_asset"

    # Add data source
    data_source = context.data_sources.add_pandas(name=data_source_name)

    # Add DataFrame asset
    data_asset = data_source.add_dataframe_asset(name=asset_name)

    # Add batch definition
    batch_definition_name = table_name
    batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

    # Get the batch and print the first few rows
    batch_parameters = {"dataframe": df_table}
    batch = batch_definition.get_batch(batch_parameters=batch_parameters)
    print(f"Batch for {table_name}:")
    print(batch.head(4))

    # Create Expectation Suite
    suite_name = f"{table_name}_expectation_suite"
    suite = gx.ExpectationSuite(name=suite_name)
    suite = context.suites.add_or_update(suite)

    # Add expectations for each expected column
    for column_info in expected_columns:
        column = column_info["column"]
        column_index = column_info["column_index"]
        column_type = column_info["type"]

        column_expectation = gx.expectations.ExpectColumnToExist(
            column=column, column_index=column_index
        )
        suite.add_expectation(column_expectation)

        dtype_expectation = gx.expectations.ExpectColumnValuesToBeOfType(
            column=column, type_=column_type
        )
        suite.add_expectation(dtype_expectation)

    # Create validation definition
    definition_name = f"{table_name}_validation_definition"
    validation_definition = gx.ValidationDefinition(
        data=batch_definition, suite=suite, name=definition_name
    )

    # Run validation
    validation_results = validation_definition.run(batch_parameters=batch_parameters)
    print(f"Validation results for {table_name}:")
    print(validation_results)
# Out:
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.DIM_ORDERS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 285.48it/s]
#                        pk_order_sid                   fk_customer_sid  \
# 0  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 1  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 2  2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
# 3  e5215415bb6f76fe3b7cb68103a0d1c0  b6f6cbfc126f1ae6723fe2f9b3751208
#
#   fk_order_purchased_date_sid fk_order_approved_at_date_sid  \
# 0                    20160913                      20161007
# 1                    20160915                      20160915
# 2                    20160904                      20161007
# 3                    20161022                          None
#
#   fk_order_delivered_carrier_date_sid fk_order_delivered_customer_date_sid  \
# 0                                None                                 None
# 1                            20161107                             20161109
# 2                            20161018                                 None
# 3                                None                                 None
#
#   fk_order_estimated_delivery_date_sid order_status  total_payment  order_amt  \
# 0                             20160930     canceled          40.95        NaN
# 1                             20161004    delivered            NaN     134.97
# 2                             20161020      shipped         136.23      72.89
# 3                             20161024     canceled          61.99        NaN
#
#    freight_amt  total_order_amt_wf_freight  balance_amt  \
# 0          NaN                         NaN          NaN
# 1         8.49                      143.46          NaN
# 2        63.34                      136.23          0.0
# 3          NaN                         NaN          NaN
#
#           payment_status  order_purchase_timestamp         order_approved_at  \
# 0  order items not found 2016-09-13 15:24:19+00:00 2016-10-07 13:16:46+00:00
# 1     payments not found 2016-09-15 12:16:38+00:00 2016-09-15 12:16:38+00:00
# 2            in progress 2016-09-04 21:15:19+00:00 2016-10-07 13:18:03+00:00
# 3  order items not found 2016-10-22 08:25:27+00:00                       NaT
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0                          NaT                           NaT
# 1    2016-11-07 17:11:53+00:00     2016-11-09 07:47:38+00:00
# 2    2016-10-18 13:14:51+00:00                           NaT
# 3                          NaT                           NaT
#
#   order_estimated_delivery_date               load_date
# 0     2016-09-30 00:00:00+00:00  2025-06-18 03:31:37 AM
# 1     2016-10-04 00:00:00+00:00  2025-06-18 03:31:37 AM
# 2     2016-10-20 00:00:00+00:00  2025-06-18 03:31:37 AM
# 3     2016-10-24 00:00:00+00:00  2025-06-18 03:31:37 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 671.16it/s]
# Validation results for olist_brazilian_ecommerce_target.DIM_ORDERS:
# {
#   "success": false,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_customer_sid",
#           "column_index": 1
#         },
#         "meta": {},
#         "id": "b6f3589d-a0c2-4f67-bea0-75d0faf3f6e5"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_customer_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "4d93ae5c-819f-4589-ac82-25331be5f285"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_purchased_date_sid",
#           "column_index": 2
#         },
#         "meta": {},
#         "id": "4d1f9ceb-b042-411f-a4e7-cce6b8d43acf"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_purchased_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "9b716694-b4e4-4b9e-b831-520529b7828e"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_approved_at_date_sid",
#           "column_index": 3
#         },
#         "meta": {},
#         "id": "7737d2a5-5e9a-4619-8043-5bb741eeff80"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_approved_at_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "1e3eead6-c09c-4daa-9e13-628865caf95a"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_delivered_carrier_date_sid",
#           "column_index": 4
#         },
#         "meta": {},
#         "id": "4016fff4-4933-4966-a091-fc3468e143f1"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_delivered_carrier_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "53633df1-4880-411c-af1e-e14823aa6c19"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_delivered_customer_date_sid",
#           "column_index": 5
#         },
#         "meta": {},
#         "id": "e6a0ccc4-0177-48e7-9349-3de0359afcf7"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_delivered_customer_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "e4c7bd81-65b5-4132-951d-cebb490d60a9"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_estimated_delivery_date_sid",
#           "column_index": 6
#         },
#         "meta": {},
#         "id": "0d505f7f-e8d0-48a2-94d5-f2b954251dec"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "fk_order_estimated_delivery_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "0dfbf91b-e041-4d99-a85c-d85bb33b2e9d"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "order_status",
#           "column_index": 7
#         },
#         "meta": {},
#         "id": "10848ab7-787a-40ad-8627-35769caa2e8d"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "order_status",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "d3504001-96c4-451d-8582-1730d2e19989"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "payment_status",
#           "column_index": 8
#         },
#         "meta": {},
#         "id": "d0fc25ab-179c-48af-8e1d-a69e2dc58c3e"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source-olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#           "column": "payment_status",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "0d7fe95e-0baf-4270-96dd-eff332878958"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.DIM_ORDERS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 16,
#     "successful_expectations": 15,
#     "unsuccessful_expectations": 1,
#     "success_percent": 93.75
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163810.709574Z",
#       "pandas_data_fingerprint": "1f74059bccd1349eb63d2e96e9b6eaed"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.DIM_ORDERS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.DIM_ORDERS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "e45092f4-4a87-40da-8adf-b9c0058477b3",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:38:10.934140+08:00"
#     },
#     "validation_time": "2025-06-19T16:38:10.934140+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_FK_SCHEMA_CHECK_FACT_TABLES

# %%
context = gx.get_context()

# List of GBQ fact tables and their foreign key columns with dtypes
gbq_tables_with_columns_index_and_types = {
    "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS": [
        {"column": "fk_order_sid", "column_index": 0, "type": "object"},
        {"column": "fk_shipping_limit_date_sid", "column_index": 3, "type": "object"},
    ],
    "olist_brazilian_ecommerce_target.FCT_PAYMENTS": [
        {"column": "fk_order_sid", "column_index": 0, "type": "object"}
    ],
    "olist_brazilian_ecommerce_target.FCT_REVIEWS": [
        {"column": "fk_order_sid", "column_index": 0, "type": "object"},
        {"column": "fk_review_creation_date_sid", "column_index": 3, "type": "object"},
    ],
}

# Iterate over the list of tables and process each one
for table_name, expected_columns in gbq_tables_with_columns_index_and_types.items():
    # Query the table from GBQ
    query = f"SELECT * FROM {table_name}"
    df_table = read_gbq(query, project_id="projectm2-aiess")

    # Generate unique names for data source and asset
    data_source_name = f"{table_name}_data_source"
    asset_name = f"{table_name}_asset"

    # Add data source
    data_source = context.data_sources.add_pandas(name=data_source_name)

    # Add DataFrame asset
    data_asset = data_source.add_dataframe_asset(name=asset_name)

    # Add batch definition
    batch_definition_name = table_name
    batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

    # Get the batch and print the first few rows
    batch_parameters = {"dataframe": df_table}
    batch = batch_definition.get_batch(batch_parameters=batch_parameters)
    print(f"Batch for {table_name}:")
    print(batch.head(4))

    # Create Expectation Suite
    suite_name = f"{table_name}_expectation_suite"
    suite = gx.ExpectationSuite(name=suite_name)
    suite = context.suites.add_or_update(suite)

    # Add expectations for each expected column
    for column_info in expected_columns:
        column = column_info["column"]
        column_index = column_info["column_index"]
        column_type = column_info["type"]

        column_expectation = gx.expectations.ExpectColumnToExist(
            column=column, column_index=column_index
        )
        suite.add_expectation(column_expectation)

        dtype_expectation = gx.expectations.ExpectColumnValuesToBeOfType(
            column=column, type_=column_type
        )
        suite.add_expectation(dtype_expectation)

    # Create validation definition
    definition_name = f"{table_name}_validation_definition"
    validation_definition = gx.ValidationDefinition(
        data=batch_definition, suite=suite, name=definition_name
    )

    # Run validation
    validation_results = validation_definition.run(batch_parameters=batch_parameters)
    print(f"Validation results for {table_name}:")
    print(validation_results)
# Out:
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 280.35it/s]
#                        fk_order_sid                       pk_order_id  \
# 0  7f39ba4c9052be115350065d07583cac  7f39ba4c9052be115350065d07583cac
# 1  9dc8d1a6f16f1b89874c29c9d8d30447  9dc8d1a6f16f1b89874c29c9d8d30447
# 2  d455a8cb295653b55abda06d434ab492  d455a8cb295653b55abda06d434ab492
# 3  5d70582531ed37f284797ba1354e0c50  5d70582531ed37f284797ba1354e0c50
#
#   pk_order_item_id fk_shipping_limit_date_sid  \
# 0                1                   20171024
# 1                1                   20171018
# 2                1                   20171012
# 3                1                   20170330
#
#                          product_id                         seller_id  \
# 0  a2ff5a97bf95719e38ea2e3b4105bce8  0015a82c2db000af6aaaf3ae2ecb0532
# 1  a2ff5a97bf95719e38ea2e3b4105bce8  0015a82c2db000af6aaaf3ae2ecb0532
# 2  a2ff5a97bf95719e38ea2e3b4105bce8  0015a82c2db000af6aaaf3ae2ecb0532
# 3  08574b074924071f4e201e151b152b4e  001cca7ae9ae17fb1caed9dfb1094831
#
#         shipping_limit_date  price  freight_value product_category_name  ...  \
# 0 2017-10-24 23:56:20+00:00  895.0          21.02       eletroportateis  ...
# 1 2017-10-18 14:49:22+00:00  895.0          21.02       eletroportateis  ...
# 2 2017-10-12 22:24:16+00:00  895.0          21.02       eletroportateis  ...
# 3 2017-03-30 13:10:09+00:00   69.9          31.23    ferramentas_jardim  ...
#
#   product_description_length  product_photos_qty  product_weight_g  \
# 0                        849                   2             11800
# 1                        849                   2             11800
# 2                        849                   2             11800
# 3                        450                   1              9000
#
#    product_length_cm  product_height_cm  product_width_cm  \
# 0                 40                 43                36
# 1                 40                 43                36
# 2                 40                 43                36
# 3                 42                 12                39
#
#    seller_zip_code_prefix  seller_city seller_state               load_date
# 0                   09080  santo andre           SP  2025-06-18 03:31:47 AM
# 1                   09080  santo andre           SP  2025-06-18 03:31:47 AM
# 2                   09080  santo andre           SP  2025-06-18 03:31:47 AM
# 3                   29156    cariacica           ES  2025-06-18 03:31:47 AM
#
# [4 rows x 22 columns]
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 570.45it/s]
# Validation results for olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "fk_order_sid",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "eace59e2-4518-40e2-970d-321304362e07"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "fk_order_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "0cb8a3e5-4cc0-4421-a41b-22214dc5e7da"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "fk_shipping_limit_date_sid",
#           "column_index": 3
#         },
#         "meta": {},
#         "id": "1e591757-2519-4891-96f2-d43e12b1f0cc"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source-olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#           "column": "fk_shipping_limit_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "d33d334a-de42-4b96-b6cb-cc0b9826421a"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 4,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163904.825906Z",
#       "pandas_data_fingerprint": "7dc15ba813450f7ca2cc0f314c3089d1"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.FCT_ORDER_ITEMS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "7e297805-f539-49d8-8790-61dceb0ab902",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:39:05.104375+08:00"
#     },
#     "validation_time": "2025-06-19T16:39:05.104375+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.FCT_PAYMENTS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 227.47it/s]
#                        fk_order_sid                       pk_order_id  \
# 0  e6670c9089973cc68e5b90b7d1f4fec4  e6670c9089973cc68e5b90b7d1f4fec4
# 1  d022bdad33a575ca5edb8c4d51e44310  d022bdad33a575ca5edb8c4d51e44310
# 2  90ea2b1be9c98c67406de151652daa63  90ea2b1be9c98c67406de151652daa63
# 3  033e33708df28579692a3d19492c6553  033e33708df28579692a3d19492c6553
#
#    pk_payment_sequential payment_type  payment_installments  payment_value  \
# 0                      1  credit_card                     1          88.49
# 1                      1       boleto                     1          70.03
# 2                      1       boleto                     1          59.22
# 3                      1  credit_card                     1         145.57
#
#                 load_date
# 0  2025-06-18 03:31:51 AM
# 1  2025-06-18 03:31:51 AM
# 2  2025-06-18 03:31:51 AM
# 3  2025-06-18 03:31:51 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 547.32it/s]
# Validation results for olist_brazilian_ecommerce_target.FCT_PAYMENTS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source-olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#           "column": "fk_order_sid",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "2837a2aa-e322-49b8-8f7e-3e0d4613be97"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source-olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#           "column": "fk_order_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "8fbd5558-8cfb-41fe-9138-709512a4a0ab"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 2,
#     "successful_expectations": 2,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T163931.632703Z",
#       "pandas_data_fingerprint": "f3ba4ad23ff07e14000b1877336df974"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.FCT_PAYMENTS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "eb7be7a5-8087-4291-bf4b-eb7f6e7e268a",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:39:31.782693+08:00"
#     },
#     "validation_time": "2025-06-19T16:39:31.782693+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }
# Downloading: 100%|██████████|
# Batch for olist_brazilian_ecommerce_target.FCT_REVIEWS:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 252.33it/s]
#                        fk_order_sid                       pk_order_id  \
# 0  809a282bbd5dbcabb6f2f724fca862ec  809a282bbd5dbcabb6f2f724fca862ec
# 1  bfbd0f9bdef84302105ad712db648a6c  bfbd0f9bdef84302105ad712db648a6c
# 2  e5215415bb6f76fe3b7cb68103a0d1c0  e5215415bb6f76fe3b7cb68103a0d1c0
# 3  8beb59392e21af5eb9547ae1a9938d06  8beb59392e21af5eb9547ae1a9938d06
#
#                        pk_review_id fk_review_creation_date_sid  review_score  \
# 0  69ac6a27fde9855ebeaaecac0f78058b                    20161002             1
# 1  6916ca4502d6d3bfd39818759d55d536                    20161006             1
# 2  49f695dffa457eaba90d388a5c37e942                    20161009             1
# 3  b28309e8253951a954123e039d3242f7                    20161020             1
#
#   review_comment_title                             review_comment_message  \
# 0                       MEU PEDIDO NÃO FOI ENTREGUE E NÃO FOI DADA NEN...
# 1                          nao recebi o produto e nem resposta da empresa
# 2                       PRODUTO NÃO CHEGOU,E JÁ PASSOU O PRAZO DE ENTREGA
# 3                       Produto não foi entregue. Não foi enviada nota...
#
#        review_creation_date   review_answer_timestamp               load_date
# 0 2016-10-02 00:00:00+00:00 2016-10-26 12:31:00+00:00  2025-06-18 03:31:55 AM
# 1 2016-10-06 00:00:00+00:00 2016-10-07 18:32:28+00:00  2025-06-18 03:31:55 AM
# 2 2016-10-09 00:00:00+00:00 2016-10-11 14:31:29+00:00  2025-06-18 03:31:55 AM
# 3 2016-10-20 00:00:00+00:00 2016-10-24 17:18:09+00:00  2025-06-18 03:31:55 AM
# Calculating Metrics: 100%|██████████| 3/3 [00:00<00:00, 671.91it/s]
# Validation results for olist_brazilian_ecommerce_target.FCT_REVIEWS:
# {
#   "success": true,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "fk_order_sid",
#           "column_index": 0
#         },
#         "meta": {},
#         "id": "3a02e39a-bcfb-44a4-ab4e-62bbfc63c5da"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "fk_order_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "7e7be4bb-8212-40dd-876e-4bcca04f2b7e"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "fk_review_creation_date_sid",
#           "column_index": 3
#         },
#         "meta": {},
#         "id": "3b1bb03b-c4dc-458d-9c71-4af6ec3cb3b7"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source-olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#           "column": "fk_review_creation_date_sid",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "66571396-115c-4738-81d5-bf52cfaecbf8"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "olist_brazilian_ecommerce_target.FCT_REVIEWS_expectation_suite",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 4,
#     "successful_expectations": 4,
#     "unsuccessful_expectations": 0,
#     "success_percent": 100.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T164018.293328Z",
#       "pandas_data_fingerprint": "ee935aa04f5515de286d3cbdf7b59ce0"
#     },
#     "active_batch_definition": {
#       "datasource_name": "olist_brazilian_ecommerce_target.FCT_REVIEWS_data_source",
#       "data_connector_name": "fluent",
#       "data_asset_name": "olist_brazilian_ecommerce_target.FCT_REVIEWS_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "6c2fb74d-0f27-49f2-90b3-8c62d9017364",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:40:18.557645+08:00"
#     },
#     "validation_time": "2025-06-19T16:40:18.557645+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %%
# Save full results to file
output_folder = "gx_output"
os.makedirs(output_folder, exist_ok=True)
result_path = os.path.join(output_folder, "gx_results_schema_check.txt")

with open(result_path, "w") as f:
    f.write(pprint.pformat(validation_results))

print(f" Full GX test results saved to {result_path}")
# Out:
#  Full GX test results saved to gx_output/gx_results_schema_check.txt
