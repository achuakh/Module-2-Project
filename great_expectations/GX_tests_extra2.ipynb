# %%
import numpy as np
import pandas as pd
import duckdb
import sqlalchemy
from pandas_gbq import read_gbq

# %%
import great_expectations as gx
from great_expectations import expectations as gxe

import pprint
import os

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_ORDERS_DELIVERY

# %%
context = gx.get_context()
# query bigquery
project_id = "projectm2-aiess"
query = "SELECT * FROM olist_brazilian_ecommerce_DS.DS_orders_delivery"
df_orders_delivery = read_gbq(query, project_id=project_id)

data_source_name = "orders_delivery_df"
data_source = context.data_sources.add_pandas(name=data_source_name)

# create asset
data_asset_name = "orders_delivery_asset"
data_asset = data_source.add_dataframe_asset(name=data_asset_name)

# create batch
batch_definition_name = "batch_orders_delivery_dataframe"
batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

batch_parameters = {"dataframe": df_orders_delivery}

new_batch = batch_definition.get_batch(batch_parameters=batch_parameters)
# Out:
# Downloading: 100%|██████████|

# %%
print(new_batch.head(4))
# Out:
# Calculating Metrics: 100%|██████████| 1/1 [00:00<00:00, 150.76it/s]
#                        pk_order_sid                   fk_customer_sid  \
# 0  809a282bbd5dbcabb6f2f724fca862ec  622e13439d6b5a0b486c435618b2679e
# 1  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 2  2e7a8482f6fb09756ca50c10d7bfc047  08c5351a6aca1c1589a38f244edeee9d
# 3  e5215415bb6f76fe3b7cb68103a0d1c0  b6f6cbfc126f1ae6723fe2f9b3751208
#
#   fk_order_purchased_date_sid fk_order_approved_at_date_sid  \
# 0                    20160913                      20161007
# 1                    20160915                      20160915
# 2                    20160904                      20161007
# 3                    20161022                          None
#
#   fk_order_delivered_carrier_date_sid fk_order_delivered_customer_date_sid  \
# 0                                None                                 None
# 1                            20161107                             20161109
# 2                            20161018                                 None
# 3                                None                                 None
#
#   fk_order_estimated_delivery_date_sid order_status  total_payment  order_amt  \
# 0                             20160930     canceled          40.95        NaN
# 1                             20161004    delivered            NaN     134.97
# 2                             20161020      shipped         136.23      72.89
# 3                             20161024     canceled          61.99        NaN
#
#    ...  order_purchase_timestamp         order_approved_at  \
# 0  ... 2016-09-13 15:24:19+00:00 2016-10-07 13:16:46+00:00
# 1  ... 2016-09-15 12:16:38+00:00 2016-09-15 12:16:38+00:00
# 2  ... 2016-09-04 21:15:19+00:00 2016-10-07 13:18:03+00:00
# 3  ... 2016-10-22 08:25:27+00:00                       NaT
#
#    order_delivered_carrier_date order_delivered_customer_date  \
# 0                           NaT                           NaT
# 1     2016-11-07 17:11:53+00:00     2016-11-09 07:47:38+00:00
# 2     2016-10-18 13:14:51+00:00                           NaT
# 3                           NaT                           NaT
#
#   order_estimated_delivery_date               load_date actual_delivery_time  \
# 0     2016-09-30 00:00:00+00:00  2025-06-18 03:31:37 AM                 None
# 1     2016-10-04 00:00:00+00:00  2025-06-18 03:31:37 AM     54 days 19:31:00
# 2     2016-10-20 00:00:00+00:00  2025-06-18 03:31:37 AM                 None
# 3     2016-10-24 00:00:00+00:00  2025-06-18 03:31:37 AM                 None
#
#   estimated delivery_time actual_delivery_time_minutes  \
# 0        16 days 08:35:41                          NaN
# 1        18 days 11:43:22                      78931.0
# 2        45 days 02:44:41                          NaN
# 3         1 days 15:34:33                          NaN
#
#   estimated-delivery_time_minutes
# 0                    23555.683333
# 1                    26623.366667
# 2                    64964.683333
# 3                     2374.550000
#
# [4 rows x 24 columns]

# %%
suite_name = "orders_delivery_expectation"
suite = gx.ExpectationSuite(name=suite_name)

# Test for column existence
actual_delivery_time_expectation = gx.expectations.ExpectColumnToExist(column="actual_delivery_time")
estimated_delivery_time_expectation = gx.expectations.ExpectColumnToExist(column="estimated delivery_time")
actual_delivery_time_minutes_expectation = gx.expectations.ExpectColumnToExist(column="actual_delivery_time_minutes")
estimated_delivery_time_minutes_expectation = gx.expectations.ExpectColumnToExist(column="estimated-delivery_time_minutes")

# %%
# Test for column values to be non-null
actual_delivery_time_nonNull_expectation = gx.expectations.ExpectColumnValuesToNotBeNull(column="actual_delivery_time")
estimated_delivery_time_nonNull_expectation = gx.expectations.ExpectColumnValuesToNotBeNull(column="estimated delivery_time")
actual_delivery_time_minutes_nonNull_expectation = gx.expectations.ExpectColumnValuesToNotBeNull(column="actual_delivery_time_minutes")
estimated_delivery_time_minutes_nonNull_expectation = gx.expectations.ExpectColumnValuesToNotBeNull(column="estimated-delivery_time_minutes")

# %%
# Test for order status value validity
order_status_validity_expectation = gx.expectations.ExpectColumnValuesToBeInSet(
        column="order_status", 
        value_set=["delivered", "shipped", "processing", "canceled", "unavailable", "invoiced", "approved", "created"]
    )

# %%
# Test for column data types
actual_delivery_time_type_expectation = gx.expectations.ExpectColumnValuesToBeOfType(column="actual_delivery_time", type_="object")
estimated_delivery_time_type_expectation = gx.expectations.ExpectColumnValuesToBeOfType(column="estimated delivery_time", type_="object")
actual_delivery_time_minutes_type_expectation = gx.expectations.ExpectColumnValuesToBeOfType(column="actual_delivery_time_minutes", type_="float")
estimated_delivery_time_minutes_type_expectation = gx.expectations.ExpectColumnValuesToBeOfType(column="estimated-delivery_time_minutes", type_="float")

# %%
# Test for column value ranges
actual_delivery_time_minutes_range_expectation = gx.expectations.ExpectColumnValuesToBeBetween(column="actual_delivery_time_minutes", min_value=0, max_value=350000)
estimated_delivery_time_minutes_range_expectation = gx.expectations.ExpectColumnValuesToBeBetween(column="estimated-delivery_time_minutes", min_value=0, max_value=350000)

# %%
# Test for consistency between columns using a row condition
actual_estimated_delivery_delta_expectation = gx.expectations.ExpectColumnValuesToBeBetween(
	column="actual_delivery_time_minutes",
	min_value=0,  # Set a minimum value
	max_value=350000,  # Set a maximum value
	row_condition="actual_delivery_time_minutes <= estimated-delivery_time_minutes",
	condition_parser="pandas"
)

# %%
context.suites.add_or_update(suite)
suite.add_expectation(actual_delivery_time_expectation)
suite.add_expectation(estimated_delivery_time_expectation)
suite.add_expectation(actual_delivery_time_minutes_expectation)
suite.add_expectation(estimated_delivery_time_minutes_expectation)
suite.add_expectation(actual_delivery_time_nonNull_expectation)
suite.add_expectation(estimated_delivery_time_nonNull_expectation)
suite.add_expectation(actual_delivery_time_minutes_nonNull_expectation)
suite.add_expectation(estimated_delivery_time_minutes_nonNull_expectation)
suite.add_expectation(order_status_validity_expectation)
suite.add_expectation(actual_delivery_time_type_expectation)
suite.add_expectation(estimated_delivery_time_type_expectation)
suite.add_expectation(actual_delivery_time_minutes_type_expectation)
suite.add_expectation(estimated_delivery_time_minutes_type_expectation)
suite.add_expectation(actual_delivery_time_minutes_range_expectation)
suite.add_expectation(estimated_delivery_time_minutes_range_expectation)
suite.add_expectation(actual_estimated_delivery_delta_expectation)

definition_name = "Orders_delivery_validation_definition"
validation_definition = gx.ValidationDefinition(
    data=batch_definition, suite=suite, name=definition_name
)

# %%
validation_results = validation_definition.run(batch_parameters=batch_parameters)
# Out:
# Calculating Metrics:  81%|████████  | 43/53 [00:00<00:00, 123.72it/s]

# %%
print(validation_results)
# Out:
# {
#   "success": false,
#   "results": [
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "column": "actual_delivery_time_minutes",
#           "row_condition": "actual_delivery_time_minutes <= estimated-delivery_time_minutes",
#           "condition_parser": "pandas",
#           "min_value": 0.0,
#           "max_value": 350000.0,
#           "batch_id": "orders_delivery_df-orders_delivery_asset"
#         },
#         "meta": {},
#         "id": "123f9e4f-2811-43c2-8654-73f0b0953576"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "MetricConfigurationID(metric_name='table.column_types', metric_domain_kwargs_id='06d7815360174726c19f75f3edd3e29e', metric_value_kwargs_id='include_nested=True')": {
#           "exception_traceback": "Traceback (most recent call last):\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/scope.py\", line 231, in resolve\n    return self.resolvers[key]\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/collections/__init__.py\", line 986, in __getitem__\n    return self.__missing__(key)            # support subclasses that define __missing__\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/collections/__init__.py\", line 978, in __missing__\n    raise KeyError(key)\nKeyError: 'estimated'\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/scope.py\", line 242, in resolve\n    return self.temps[key]\nKeyError: 'estimated'\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/execution_engine/execution_engine.py\", line 534, in _process_direct_and_bundled_metric_computation_configurations\n    metric_computation_configuration.metric_fn(  # type: ignore[misc] # F not callable\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/expectations/metrics/metric_provider.py\", line 60, in inner_func\n    return metric_fn(*args, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/expectations/metrics/table_metrics/table_column_types.py\", line 37, in _pandas\n    df, _, _ = execution_engine.get_compute_domain(\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/execution_engine/pandas_execution_engine.py\", line 628, in get_compute_domain\n    data: pd.DataFrame = self.get_domain_records(domain_kwargs=domain_kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/execution_engine/pandas_execution_engine.py\", line 532, in get_domain_records\n    data = data.query(row_condition, parser=condition_parser)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/frame.py\", line 4599, in query\n    res = self.eval(expr, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/frame.py\", line 4725, in eval\n    return _eval(expr, inplace=inplace, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/eval.py\", line 336, in eval\n    parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 808, in __init__\n    self.terms = self.parse()\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 827, in parse\n    return self._visitor.visit(self.expr)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 411, in visit\n    return visitor(node, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 417, in visit_Module\n    return self.visit(expr, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 411, in visit\n    return visitor(node, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 420, in visit_Expr\n    return self.visit(node.value, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 411, in visit\n    return visitor(node, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 718, in v ...
#           "exception_message": "name 'estimated' is not defined",
#           "raised_exception": true
#         },
#         "MetricConfigurationID(metric_name='table.row_count', metric_domain_kwargs_id='06d7815360174726c19f75f3edd3e29e', metric_value_kwargs_id=())": {
#           "exception_traceback": "Traceback (most recent call last):\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/scope.py\", line 231, in resolve\n    return self.resolvers[key]\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/collections/__init__.py\", line 986, in __getitem__\n    return self.__missing__(key)            # support subclasses that define __missing__\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/collections/__init__.py\", line 978, in __missing__\n    raise KeyError(key)\nKeyError: 'estimated'\n\nDuring handling of the above exception, another exception occurred:\n\nTraceback (most recent call last):\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/scope.py\", line 242, in resolve\n    return self.temps[key]\nKeyError: 'estimated'\n\nThe above exception was the direct cause of the following exception:\n\nTraceback (most recent call last):\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/execution_engine/execution_engine.py\", line 534, in _process_direct_and_bundled_metric_computation_configurations\n    metric_computation_configuration.metric_fn(  # type: ignore[misc] # F not callable\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/expectations/metrics/metric_provider.py\", line 60, in inner_func\n    return metric_fn(*args, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/expectations/metrics/table_metrics/table_row_count.py\", line 35, in _pandas\n    df, _, _ = execution_engine.get_compute_domain(\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/execution_engine/pandas_execution_engine.py\", line 628, in get_compute_domain\n    data: pd.DataFrame = self.get_domain_records(domain_kwargs=domain_kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/great_expectations/execution_engine/pandas_execution_engine.py\", line 532, in get_domain_records\n    data = data.query(row_condition, parser=condition_parser)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/frame.py\", line 4599, in query\n    res = self.eval(expr, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/frame.py\", line 4725, in eval\n    return _eval(expr, inplace=inplace, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/eval.py\", line 336, in eval\n    parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 808, in __init__\n    self.terms = self.parse()\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 827, in parse\n    return self._visitor.visit(self.expr)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 411, in visit\n    return visitor(node, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 417, in visit_Module\n    return self.visit(expr, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 411, in visit\n    return visitor(node, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 420, in visit_Expr\n    return self.visit(node.value, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 411, in visit\n    return visitor(node, **kwargs)\n  File \"/Users/andrew/miniconda3/envs/elt/lib/python3.10/site-packages/pandas/core/computation/expr.py\", line 718, in visi ...
#           "exception_message": "name 'estimated' is not defined",
#           "raised_exception": true
#         }
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time"
#         },
#         "meta": {},
#         "id": "4a3caac5-cc7b-4a4d-9d9c-f70547c63dbf"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time"
#         },
#         "meta": {},
#         "id": "0f72068e-8657-4e02-aed7-6fc460311c11"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 2965,
#         "unexpected_percent": 2.981667521444877,
#         "partial_unexpected_list": [
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null
#         ],
#         "partial_unexpected_counts": [
#           {
#             "value": null,
#             "count": 20
#           }
#         ],
#         "partial_unexpected_index_list": [
#           0,
#           2,
#           3,
#           4,
#           6,
#           8,
#           9,
#           10,
#           11,
#           12,
#           13,
#           14,
#           15,
#           16,
#           22,
#           26,
#           27,
#           36,
#           41,
#           45
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "7a45e668-91a0-4dfa-9f3c-d07f9ec26579"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated delivery_time"
#         },
#         "meta": {},
#         "id": "df810c82-746b-4f90-a461-8ce04a353aec"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated delivery_time"
#         },
#         "meta": {},
#         "id": "5c5b8075-743a-4953-b847-c0958745f6c7"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated delivery_time",
#           "type_": "object"
#         },
#         "meta": {},
#         "id": "6bdc720d-f5d9-4cc4-a74d-8fb646e2c830"
#       },
#       "result": {
#         "observed_value": "object_"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time_minutes"
#         },
#         "meta": {},
#         "id": "67e2be50-68b4-4cb3-a1d0-b793ceddf5be"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time_minutes"
#         },
#         "meta": {},
#         "id": "a1212339-4cf4-40b0-8978-391ac46a84e0"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 2965,
#         "unexpected_percent": 2.981667521444877,
#         "partial_unexpected_list": [
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null,
#           null
#         ],
#         "partial_unexpected_counts": [
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           },
#           {
#             "value": null,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           0,
#           2,
#           3,
#           4,
#           6,
#           8,
#           9,
#           10,
#           11,
#           12,
#           13,
#           14,
#           15,
#           16,
#           22,
#           26,
#           27,
#           36,
#           41,
#           45
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time_minutes",
#           "type_": "float"
#         },
#         "meta": {},
#         "id": "768b32b2-5e53-426d-918e-eafa8b6824f8"
#       },
#       "result": {
#         "observed_value": "float64"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "actual_delivery_time_minutes",
#           "min_value": 0.0,
#           "max_value": 350000.0
#         },
#         "meta": {},
#         "id": "0ea6b5f1-511a-4fc0-9995-db8fdc2e5af7"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 2965,
#         "missing_percent": 2.981667521444877,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_to_exist",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated-delivery_time_minutes"
#         },
#         "meta": {},
#         "id": "5c23b6d7-d712-46a8-97ad-0b8c2030bf5a"
#       },
#       "result": {},
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_not_be_null",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated-delivery_time_minutes"
#         },
#         "meta": {},
#         "id": "32f16325-1a42-4ee6-9848-7657d5b87203"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_of_type",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated-delivery_time_minutes",
#           "type_": "float"
#         },
#         "meta": {},
#         "id": "dcb8a202-8e54-448a-b828-a690e873f654"
#       },
#       "result": {
#         "observed_value": "float64"
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "estimated-delivery_time_minutes",
#           "min_value": 0.0,
#           "max_value": 350000.0
#         },
#         "meta": {},
#         "id": "f9139077-a21e-4bbc-a38e-662175355e9b"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_in_set",
#         "kwargs": {
#           "batch_id": "orders_delivery_df-orders_delivery_asset",
#           "column": "order_status",
#           "value_set": [
#             "delivered",
#             "shipped",
#             "processing",
#             "canceled",
#             "unavailable",
#             "invoiced",
#             "approved",
#             "created"
#           ]
#         },
#         "meta": {},
#         "id": "1f351e92-c7b3-409d-96ae-c26d5e410b1f"
#       },
#       "result": {
#         "element_count": 99441,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "orders_delivery_expectation",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 16,
#     "successful_expectations": 13,
#     "unsuccessful_expectations": 3,
#     "success_percent": 81.25
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T162521.148164Z",
#       "pandas_data_fingerprint": "1b34ebd25aab117defbd7f0fe117d18c"
#     },
#     "active_batch_definition": {
#       "datasource_name": "orders_delivery_df",
#       "data_connector_name": "fluent",
#       "data_asset_name": "orders_delivery_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "5842e427-62f5-4eb5-a4d2-94636c34fbc6",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:25:21.872108+08:00"
#     },
#     "validation_time": "2025-06-19T16:25:21.872108+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %%
# Save full results to file
output_folder = "gx_output"
os.makedirs(output_folder, exist_ok=True)
result_path = os.path.join(output_folder, "gx_results_orders_delivery.txt")

with open(result_path, "w") as f:
    f.write(pprint.pformat(validation_results))

print(f" Full GX test results saved to {result_path}")
# Out:
#  Full GX test results saved to gx_output/gx_results_orders_delivery.txt

# %% [markdown]
# <div class="alert alert-block alert-info">
# GX_geo

# %%
context = gx.get_context()
# query bigquery
project_id = "projectm2-aiess"
query = "SELECT * FROM olist_brazilian_ecommerce_DS.DS_land_geolocation"
df_geolocation = read_gbq(query, project_id=project_id)

data_source_name = "geolocation_df"
data_source = context.data_sources.add_pandas(name=data_source_name)

# create asset
data_asset_name = "geolocation_asset"
data_asset = data_source.add_dataframe_asset(name=data_asset_name)

# create batch
batch_definition_name = "batch_geolocation_dataframe"
batch_definition = data_asset.add_batch_definition_whole_dataframe(batch_definition_name)

batch_parameters = {"dataframe": df_geolocation}

new_batch = batch_definition.get_batch(batch_parameters=batch_parameters)
# Out:
# Downloading: 100%|██████████|

# %%
suite_name = "br_ecom_expectation"
suite = gx.ExpectationSuite(name=suite_name)

preset_lat_expectation = gx.expectations.ExpectColumnValuesToBeBetween(
    column="geolocation_lat", min_value=-35, max_value=5
)

preset_long_expectation = gx.expectations.ExpectColumnValuesToBeBetween(
    column="geolocation_lng", min_value=-75, max_value=-35
)

context.suites.add_or_update(suite)
suite.add_expectation(preset_lat_expectation)
suite.add_expectation(preset_long_expectation)

definition_name = "br_ecom_validation_definition_V2"
validation_definition = gx.ValidationDefinition(
    data=batch_definition, suite=suite, name=definition_name
)

# %%
validation_results = validation_definition.run(batch_parameters=batch_parameters)
print(validation_results)
# Out:
# Calculating Metrics: 100%|██████████| 17/17 [00:00<00:00, 28.63it/s]
# {
#   "success": false,
#   "results": [
#     {
#       "success": true,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "geolocation_df-geolocation_asset",
#           "column": "geolocation_lat",
#           "min_value": -35.0,
#           "max_value": 5.0
#         },
#         "meta": {},
#         "id": "1c3a15ed-1370-44bd-b15c-f500b3924999"
#       },
#       "result": {
#         "element_count": 738299,
#         "unexpected_count": 0,
#         "unexpected_percent": 0.0,
#         "partial_unexpected_list": [],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 0.0,
#         "unexpected_percent_nonmissing": 0.0,
#         "partial_unexpected_counts": [],
#         "partial_unexpected_index_list": []
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     },
#     {
#       "success": false,
#       "expectation_config": {
#         "type": "expect_column_values_to_be_between",
#         "kwargs": {
#           "batch_id": "geolocation_df-geolocation_asset",
#           "column": "geolocation_lng",
#           "min_value": -75.0,
#           "max_value": -35.0
#         },
#         "meta": {},
#         "id": "be894134-dbdb-418d-9d27-ff05a8c25a84"
#       },
#       "result": {
#         "element_count": 738299,
#         "unexpected_count": 9021,
#         "unexpected_percent": 1.2218626870685183,
#         "partial_unexpected_list": [
#           -34.8986178702464,
#           -34.9004323113108,
#           -34.8991993508425,
#           -34.900806986814,
#           -34.8993922163426,
#           -34.8974481385628,
#           -34.9023807618847,
#           -34.9067026150299,
#           -34.9138294348155,
#           -34.9023532137209,
#           -34.9077948480934,
#           -34.90248,
#           -34.9009879139308,
#           -34.9011355453068,
#           -34.9000304594152,
#           -34.9063250899566,
#           -34.9027399348706,
#           -34.901220298375,
#           -34.9037988954785,
#           -34.90554467849
#         ],
#         "missing_count": 0,
#         "missing_percent": 0.0,
#         "unexpected_percent_total": 1.2218626870685183,
#         "unexpected_percent_nonmissing": 1.2218626870685183,
#         "partial_unexpected_counts": [
#           {
#             "value": -34.9138294348155,
#             "count": 1
#           },
#           {
#             "value": -34.9077948480934,
#             "count": 1
#           },
#           {
#             "value": -34.9067026150299,
#             "count": 1
#           },
#           {
#             "value": -34.9063250899566,
#             "count": 1
#           },
#           {
#             "value": -34.90554467849,
#             "count": 1
#           },
#           {
#             "value": -34.9037988954785,
#             "count": 1
#           },
#           {
#             "value": -34.9027399348706,
#             "count": 1
#           },
#           {
#             "value": -34.90248,
#             "count": 1
#           },
#           {
#             "value": -34.9023807618847,
#             "count": 1
#           },
#           {
#             "value": -34.9023532137209,
#             "count": 1
#           },
#           {
#             "value": -34.901220298375,
#             "count": 1
#           },
#           {
#             "value": -34.9011355453068,
#             "count": 1
#           },
#           {
#             "value": -34.9009879139308,
#             "count": 1
#           },
#           {
#             "value": -34.900806986814,
#             "count": 1
#           },
#           {
#             "value": -34.9004323113108,
#             "count": 1
#           },
#           {
#             "value": -34.9000304594152,
#             "count": 1
#           },
#           {
#             "value": -34.8993922163426,
#             "count": 1
#           },
#           {
#             "value": -34.8991993508425,
#             "count": 1
#           },
#           {
#             "value": -34.8986178702464,
#             "count": 1
#           },
#           {
#             "value": -34.8974481385628,
#             "count": 1
#           }
#         ],
#         "partial_unexpected_index_list": [
#           480,
#           481,
#           482,
#           483,
#           484,
#           485,
#           486,
#           487,
#           488,
#           489,
#           490,
#           491,
#           492,
#           493,
#           494,
#           495,
#           496,
#           497,
#           498,
#           499
#         ]
#       },
#       "meta": {},
#       "exception_info": {
#         "raised_exception": false,
#         "exception_traceback": null,
#         "exception_message": null
#       }
#     }
#   ],
#   "suite_name": "br_ecom_expectation",
#   "suite_parameters": {},
#   "statistics": {
#     "evaluated_expectations": 2,
#     "successful_expectations": 1,
#     "unsuccessful_expectations": 1,
#     "success_percent": 50.0
#   },
#   "meta": {
#     "great_expectations_version": "1.4.6",
#     "batch_spec": {
#       "batch_data": "PandasDataFrame"
#     },
#     "batch_markers": {
#       "ge_load_time": "20250619T162711.068501Z",
#       "pandas_data_fingerprint": "267fd3c48d6982672c5024bcd6c3c296"
#     },
#     "active_batch_definition": {
#       "datasource_name": "geolocation_df",
#       "data_connector_name": "fluent",
#       "data_asset_name": "geolocation_asset",
#       "batch_identifiers": {
#         "dataframe": "<DATAFRAME>"
#       }
#     },
#     "validation_id": "c4c45243-87b6-4231-b6e5-34fd29de1b09",
#     "checkpoint_id": null,
#     "run_id": {
#       "run_name": null,
#       "run_time": "2025-06-20T00:27:12.009025+08:00"
#     },
#     "validation_time": "2025-06-19T16:27:12.009025+00:00",
#     "batch_parameters": {
#       "dataframe": "<DATAFRAME>"
#     }
#   },
#   "id": null
# }

# %%
# Save full results to file
output_folder = "gx_output"
os.makedirs(output_folder, exist_ok=True)
result_path = os.path.join(output_folder, "gx_results_geo.txt")

with open(result_path, "w") as f:
    f.write(pprint.pformat(validation_results))

print(f" Full GX test results saved to {result_path}")
# Out:
#  Full GX test results saved to gx_output/gx_results_geo.txt
